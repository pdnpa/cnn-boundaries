# %%
# %load_ext autoreload
# %autoreload 2

# %%
# set fresh env for keras install Python >= 3.9 | TensorFlow = Version: 2.14.0 | Keras-ocr = Version: 0.9.2
import os, sys
sys.path.append('../scripts/')
import keras_ocr
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd

# not setup with cuda yet

# %%
pipeline = keras_ocr.pipeline.Pipeline()
#read image from the an image path (a jpg/png file or an image url)
img = keras_ocr.tools.read("../content/tifs/189226695.27.tif")
# Prediction_groups is a list of (word, box) tuples
prediction_groups = pipeline.recognize([img])
#print image with annotation and boxes
keras_ocr.tools.drawAnnotations(image=img, predictions=prediction_groups[0])
# Out:
# Looking for C:\Users\alexad\.keras-ocr\craft_mlt_25k.h5
# Downloading C:\Users\alexad\.keras-ocr\craft_mlt_25k.h5
# WARNING:tensorflow:From c:\Users\alexad\Documents\GitHub\cnn-boundaries\keras\lib\site-packages\tensorflow\python\util\dispatch.py:1260: resize_bilinear (from tensorflow.python.ops.image_ops_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.image.resize(...method=ResizeMethod.BILINEAR...)` instead.
# Looking for C:\Users\alexad\.keras-ocr\crnn_kurapan.h5
# Downloading C:\Users\alexad\.keras-ocr\crnn_kurapan.h5
# 1/1 [==============================] - 5s 5s/step
# 2/2 [==============================] - 2s 172ms/step
# <Axes: >

# %%
df = pd.DataFrame(prediction_groups)

# %%
df.head(100)
# Out:
#                                                   0   \
# 0  (len, [[720.5625, 2047.3125], [880.6875, 2047....
#
#                                                   1   \
# 0  (lloiril, [[7182.75, 2401.875], [7457.25, 2401...
#
#                                                   2   \
# 0  (luiaed, [[1166.625, 2722.125], [1315.3125, 27...
#
#                                                   3   \
# 0  (dd, [[1326.75, 2722.125], [1429.6875, 2722.12...
#
#                                                   4   \
# 0  (thler, [[846.375, 2813.625], [983.625, 2813.6...
#
#                                                   5   \
# 0  (nert, [[1006.5, 2813.625], [1132.3125, 2813.6...
#
#                                                   6   \
# 0  (dggles, [[3454.125, 2825.0625], [3602.8125, 2...
#
#                                                   7   \
# 0  (ashford, [[6199.125, 2916.5625], [6759.5625, ...
#
#                                                   8   \
# 0  (water, [[7171.3125, 2916.5625], [7594.5, 2916...
#
#                                                   9   ...  \
# 0  (uhe, [[6942.5625, 2939.4375], [7137.0, 2939.4...  ...
#
#                                                   30  \
# 0  (haddon, [[6711.707, 7045.555], [7890.7593, 70...
#
#                                                   31  \
# 0  (te, [[5878.875, 7034.0625], [6290.625, 7034.0...
#
#                                                   32  \
# 0  (lichit, [[2859.375, 7056.9375], [2996.625, 70...
#
#                                                   33  \
# 0  (r, [[6279.1875, 7045.5], [6439.3125, 7045.5],...
#
#                                                   34  \
# 0  (wltns, [[6039.0, 7182.75], [6256.3125, 7182.7...
#
#                                                   35  \
# 0  (oles, [[7274.25, 7182.75], [7434.375, 7182.75...
#
#                                                   36  \
# 0  (de, [[7102.6875, 7297.125], [7194.1875, 7297....
#
#                                                   37  \
# 0  (len, [[7182.75, 7308.5625], [7274.25, 7308.56...
#
#                                                   38  \
# 0  (getal, [[1749.9375, 7525.875], [1898.625, 752...
#
#                                                   39
# 0  (caleg, [[5226.9375, 9024.1875], [5375.625, 90...
#
# [1 rows x 40 columns]

# %%
# Plot the predictions
fig, axs = plt.subplots(nrows=len(img), figsize=(20, 20))
for ax, image, predictions in zip(axs, img, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=img, predictions=predictions, ax=ax)
